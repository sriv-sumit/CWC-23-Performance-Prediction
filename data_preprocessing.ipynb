# %%
import pandas as pd
import json

# %%
with open('json files\match_results.json') as f:
    data = json.load(f)
df_match = pd.DataFrame(data['matchSummary'])
df_match
# Out:
#            team1         team2        winner     margin        ground  \
# 0          India     Australia     Australia  6 wickets     Ahmedabad
# 1      Australia  South Africa     Australia  3 wickets  Eden Gardens
# 2          India   New Zealand         India    70 runs      Wankhede
# 3          India   Netherlands         India   160 runs     Bengaluru
# 4        England      Pakistan       England    93 runs  Eden Gardens
# 5      Australia    Bangladesh     Australia  8 wickets          Pune
# 6    Afghanistan  South Africa  South Africa  5 wickets     Ahmedabad
# 7    New Zealand     Sri Lanka   New Zealand  5 wickets     Bengaluru
# 8        England   Netherlands       England   160 runs          Pune
# 9    Afghanistan     Australia     Australia  3 wickets      Wankhede
# 10    Bangladesh     Sri Lanka    Bangladesh  3 wickets         Delhi
# 11         India  South Africa         India   243 runs  Eden Gardens
# ...

# %%
df_match.shape
# Out:
# (48, 7)

# %%
df_match.rename({'scorecard': 'match_id'}, axis = 1, inplace = True)
df_match.head()
# Out:
#        team1         team2     winner     margin        ground     matchDate  \
# 0      India     Australia  Australia  6 wickets     Ahmedabad  Nov 19, 2023
# 1  Australia  South Africa  Australia  3 wickets  Eden Gardens  Nov 16, 2023
# 2      India   New Zealand      India    70 runs      Wankhede  Nov 15, 2023
# 3      India   Netherlands      India   160 runs     Bengaluru  Nov 12, 2023
# 4    England      Pakistan    England    93 runs  Eden Gardens  Nov 11, 2023
#
#      match_id
# 0  ODI # 4705
# 1  ODI # 4704
# 2  ODI # 4703
# 3  ODI # 4702
# 4  ODI # 4701

# %%
match_ids_dict = {}

for index, row in df_match.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    match_ids_dict[key1] = row['match_id']
    match_ids_dict[key2] = row['match_id']

# %%
df_match.to_csv('json files\dim_match_summary.csv', index = False)

# %%
with open('json files/battinng_summary.json') as f:
    data = json.load(f)
    all_records = []
    for rec in data:
        all_records.extend(rec['battingSummary'])
  
df_batting = pd.DataFrame(all_records)
df_batting.head(11)
# Out:
#                  match teamInnings  battingPos       batsmanName  \
# 0   India Vs Australia       India           1   Rohit Sharma(c)
# 1   India Vs Australia       India           2      Shubman Gill
# 2   India Vs Australia       India           3       Virat Kohli
# 3   India Vs Australia       India           4      Shreyas Iyer
# 4   India Vs Australia       India           5       KL Rahulâ€
# 5   India Vs Australia       India           6   Ravindra Jadeja
# 6   India Vs Australia       India           7  Suryakumar Yadav
# 7   India Vs Australia       India           8    Mohammed Shami
# 8   India Vs Australia       India           9    Jasprit Bumrah
# 9   India Vs Australia       India          10     Kuldeep Yadav
# 10  India Vs Australia       India          11    Mohammed Siraj
#
#                         dismissal runs balls 4s 6s      SR
# 0                c Head b Maxwell   47    31  4  3  151.61
# 1                 c Zampa b Starc    4     7  0  0   57.14
# ...

# %%
df_batting['dismissal'].fillna('', inplace=True)
df_batting['out/not_out'] = df_batting.dismissal.apply(lambda x: "out" if isinstance(x, str) and len(x) > 0 else "not_out")
df_batting.head(11)
# Out:
#                  match teamInnings  battingPos       batsmanName  \
# 0   India Vs Australia       India           1   Rohit Sharma(c)
# 1   India Vs Australia       India           2      Shubman Gill
# 2   India Vs Australia       India           3       Virat Kohli
# 3   India Vs Australia       India           4      Shreyas Iyer
# 4   India Vs Australia       India           5       KL Rahulâ€
# 5   India Vs Australia       India           6   Ravindra Jadeja
# 6   India Vs Australia       India           7  Suryakumar Yadav
# 7   India Vs Australia       India           8    Mohammed Shami
# 8   India Vs Australia       India           9    Jasprit Bumrah
# 9   India Vs Australia       India          10     Kuldeep Yadav
# 10  India Vs Australia       India          11    Mohammed Siraj
#
#                         dismissal runs balls 4s 6s      SR out/not_out
# 0                c Head b Maxwell   47    31  4  3  151.61         out
# ...

# %%
df_batting['match_id'] = df_batting['match'].map(match_ids_dict)
df_batting.head()
# Out:
#                 match teamInnings  battingPos      batsmanName  \
# 0  India Vs Australia       India           1  Rohit Sharma(c)
# 1  India Vs Australia       India           2     Shubman Gill
# 2  India Vs Australia       India           3      Virat Kohli
# 3  India Vs Australia       India           4     Shreyas Iyer
# 4  India Vs Australia       India           5      KL Rahulâ€
#
#                dismissal runs balls 4s 6s      SR out/not_out    match_id
# 0       c Head b Maxwell   47    31  4  3  151.61         out  ODI # 4662
# 1        c Zampa b Starc    4     7  0  0   57.14         out  ODI # 4662
# 2              b Cummins   54    63  4  0   85.71         out  ODI # 4662
# 3  c â€ Inglis b Cummins    4     3  1  0  133.33         out  ODI # 4662
# 4    c â€ Inglis b Starc   66   107  1  0   61.68         out  ODI # 4662

# %%
df_batting.drop(columns=["dismissal"], inplace=True)
df_batting.head(10)
# Out:
#                 match teamInnings  battingPos       batsmanName runs balls 4s  \
# 0  India Vs Australia       India           1   Rohit Sharma(c)   47    31  4
# 1  India Vs Australia       India           2      Shubman Gill    4     7  0
# 2  India Vs Australia       India           3       Virat Kohli   54    63  4
# 3  India Vs Australia       India           4      Shreyas Iyer    4     3  1
# 4  India Vs Australia       India           5       KL Rahulâ€    66   107  1
# 5  India Vs Australia       India           6   Ravindra Jadeja    9    22  0
# 6  India Vs Australia       India           7  Suryakumar Yadav   18    28  1
# 7  India Vs Australia       India           8    Mohammed Shami    6    10  1
# 8  India Vs Australia       India           9    Jasprit Bumrah    1     3  0
# 9  India Vs Australia       India          10     Kuldeep Yadav   10    18  0
#
#   6s      SR out/not_out    match_id
# 0  3  151.61         out  ODI # 4662
# ...

# %%
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('â€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('\xa0', ''))
df_batting.head()
# Out:
#                 match teamInnings  battingPos      batsmanName runs balls 4s  \
# 0  India Vs Australia       India           1  Rohit Sharma(c)   47    31  4
# 1  India Vs Australia       India           2     Shubman Gill    4     7  0
# 2  India Vs Australia       India           3      Virat Kohli   54    63  4
# 3  India Vs Australia       India           4     Shreyas Iyer    4     3  1
# 4  India Vs Australia       India           5         KL Rahul   66   107  1
#
#   6s      SR out/not_out    match_id
# 0  3  151.61         out  ODI # 4662
# 1  0   57.14         out  ODI # 4662
# 2  0   85.71         out  ODI # 4662
# 3  0  133.33         out  ODI # 4662
# 4  0   61.68         out  ODI # 4662

# %%
df_batting.shape
# Out:
# (876, 11)

# %%
df_batting.to_csv('json files/fact_bating_summary.csv', index = False)

# %%
with open('json files/bowling_summary.json') as f:
    data = json.load(f)
    all_records = []
    for rec in data:
        all_records.extend(rec['bowlingSummary'])
all_records[:2]
# Out:
# [{'match': 'India Vs Australia',
#   'bowlingTeam': 'Australia',
#   'bowlerName': 'Mitchell Starc',
#   'overs': '10',
#   'maiden': '0',
#   'runs': '55',
#   'wickets': '3',
#   'economy': '5.50',
#   '0s': '30',
#   '4s': '4',
#   '6s': '1',
#   'wides': '3',
#   'noBalls': '0'},
#  {'match': 'India Vs Australia',
#   'bowlingTeam': 'Australia',
#   'bowlerName': 'Josh Hazlewood',
#   'overs': '10',
#   'maiden': '0',
#   'runs': '60',
#   'wickets': '2',
#   'economy': '6.00',
#   '0s': '22',
#   '4s': '4',
#   '6s': '1',
#   'wides': '1',
#   'noBalls': '0'}]

# %%
df_bowling = pd.DataFrame(all_records)
print(df_bowling.shape)
df_bowling.head()
# Out:
# (574, 13)
#                 match bowlingTeam      bowlerName overs maiden runs wickets  \
# 0  India Vs Australia   Australia  Mitchell Starc    10      0   55       3
# 1  India Vs Australia   Australia  Josh Hazlewood    10      0   60       2
# 2  India Vs Australia   Australia   Glenn Maxwell     6      0   35       1
# 3  India Vs Australia   Australia     Pat Cummins    10      0   34       2
# 4  India Vs Australia   Australia      Adam Zampa    10      0   44       1
#
#   economy  0s 4s 6s wides noBalls
# 0    5.50  30  4  1     3       0
# 1    6.00  22  4  1     1       0
# 2    5.83  19  4  1     0       0
# 3    3.40  30  0  0     2       0
# 4    4.40  22  1  0     1       0

# %%
df_bowling['match_id'] = df_bowling['match'].map(match_ids_dict)
df_bowling.head()
# Out:
#                 match bowlingTeam      bowlerName overs maiden runs wickets  \
# 0  India Vs Australia   Australia  Mitchell Starc    10      0   55       3
# 1  India Vs Australia   Australia  Josh Hazlewood    10      0   60       2
# 2  India Vs Australia   Australia   Glenn Maxwell     6      0   35       1
# 3  India Vs Australia   Australia     Pat Cummins    10      0   34       2
# 4  India Vs Australia   Australia      Adam Zampa    10      0   44       1
#
#   economy  0s 4s 6s wides noBalls    match_id
# 0    5.50  30  4  1     3       0  ODI # 4662
# 1    6.00  22  4  1     1       0  ODI # 4662
# 2    5.83  19  4  1     0       0  ODI # 4662
# 3    3.40  30  0  0     2       0  ODI # 4662
# 4    4.40  22  1  0     1       0  ODI # 4662

# %%
df_bowling.to_csv('json files/fact_bowling_summary.csv', index = False)

# %%
with open('json files/player_info.json') as f:
    data = json.load(f)

# %%
df_players = pd.DataFrame(data)

print(df_players.shape)
df_players.head(10)
# Out:
# (630, 7)
#                        name       team    battingStyle          playingRole  \
# 0              Tanzid Hasan  Australia   Left hand Bat       Opening Batter
# 1                Litton Das  Australia  Right hand Bat  Wicketkeeper Batter
# 2  Najmul Hossain Shanto(c)  Australia   Left hand Bat     Top order Batter
# 3             Towhid Hridoy  Australia  Right hand Bat     Top order Batter
# 4               Mahmudullah  Australia  Right hand Bat           Allrounder
# 5        Mushfiqur Rahimâ€   Australia  Right hand Bat  Wicketkeeper Batter
# 6        Mehidy Hasan Miraz  Australia  Right hand Bat           Allrounder
# 7               Nasum Ahmed  Australia   Left hand Bat               Bowler
# 8              Mahedi Hasan  Australia  Right hand Bat           Allrounder
# 9              Taskin Ahmed  Australia   Left hand Bat               Bowler
#
#   input            bowlingStyle  \
# 0    {}                     NaN
# 1    {}      Right arm Offbreak
# ...

# %%
df_players['name'] = df_players['name'].apply(lambda x: x.replace('â€', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('†', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('\xa0', ''))
df_players.head(10)
# Out:
#                        name       team    battingStyle          playingRole  \
# 0              Tanzid Hasan  Australia   Left hand Bat       Opening Batter
# 1                Litton Das  Australia  Right hand Bat  Wicketkeeper Batter
# 2  Najmul Hossain Shanto(c)  Australia   Left hand Bat     Top order Batter
# 3             Towhid Hridoy  Australia  Right hand Bat     Top order Batter
# 4               Mahmudullah  Australia  Right hand Bat           Allrounder
# 5           Mushfiqur Rahim  Australia  Right hand Bat  Wicketkeeper Batter
# 6        Mehidy Hasan Miraz  Australia  Right hand Bat           Allrounder
# 7               Nasum Ahmed  Australia   Left hand Bat               Bowler
# 8              Mahedi Hasan  Australia  Right hand Bat           Allrounder
# 9              Taskin Ahmed  Australia   Left hand Bat               Bowler
#
#   input            bowlingStyle  \
# 0    {}                     NaN
# 1    {}      Right arm Offbreak
# ...

# %%
df_players[df_players['team'] == 'India']
# Out:
#                         name   team    battingStyle          playingRole  \
# 20        Rahmanullah Gurbaz  India  Right hand Bat  Wicketkeeper Batter
# 21            Ibrahim Zadran  India  Right hand Bat       Opening Batter
# 22               Rahmat Shah  India  Right hand Bat           Allrounder
# 23   Hashmatullah Shahidi(c)  India   Left hand Bat     Top order Batter
# 24        Azmatullah Omarzai  India  Right hand Bat           Allrounder
# ..                       ...    ...             ...                  ...
# 512              Mahmudullah  India  Right hand Bat           Allrounder
# 513              Nasum Ahmed  India   Left hand Bat               Bowler
# 514        Mustafizur Rahman  India   Left hand Bat               Bowler
# 515           Shoriful Islam  India   Left hand Bat               Bowler
# 527             Hasan Mahmud  India  Right hand Bat               Bowler
#
#     input            bowlingStyle  \
# 20     {}                     NaN
# ...

# %%
df_players.to_csv('json files/dim_players_no_images.csv', index = False)
